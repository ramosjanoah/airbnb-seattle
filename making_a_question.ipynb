# %% [markdown]
# # Import Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calendar = pd.read_csv('seattle/calendar.csv')
listings = pd.read_csv('seattle/listings.csv')
reviews = pd.read_csv('seattle/reviews.csv')

# %%
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
listings_price = listings.price.replace('[\$,]', '', regex=True).astype(float)

# %%
listings_price.hist(bins=200)

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
listings[['review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']];
listings.review_scores_value.hist(bins=10)

# %%
calendar.head();
listings
# Out:
# 0       2016-01-04
# 1       2016-01-04
# 2       2016-01-04
# 3       2016-01-04
# 4       2016-01-04
# 5       2016-01-04
# 6       2016-01-04
# 7       2016-01-04
# 8       2016-01-04
# 9       2016-01-04
# 10      2016-01-04
# 11      2016-01-04
# 12      2016-01-04
# 13      2016-01-04
# 14      2016-01-04
# 15      2016-01-04
# 16      2016-01-04
# 17      2016-01-04
# 18      2016-01-04
# 19      2016-01-04
# 20      2016-01-04
# 21      2016-01-04
# 22      2016-01-04
# 23      2016-01-04
# 24      2016-01-04
# 25      2016-01-04
# 26      2016-01-04
# 27      2016-01-04
# 28      2016-01-04
# 29      2016-01-04
#            ...
# 3788    2016-01-04
# 3789    2016-01-04
# 3790    2016-01-04
# 3791    2016-01-04
# 3792    2016-01-04
# 3793    2016-01-04
# 3794    2016-01-04
# 3795    2016-01-04
# 3796    2016-01-04
# 3797    2016-01-04
# 3798    2016-01-04
# 3799    2016-01-04
# 3800    2016-01-04
# 3801    2016-01-04
# 3802    2016-01-04
# 3803    2016-01-04
# ...

# %% [markdown]
# # Understanding the dataset

# %% [markdown]
# ## 1. Understanding the column

# %%
describe_calendar = calendar.groupby('listing_id').describe()

# %%
describe_calendar_listing_id = calendar.groupby('listing_id').describe()

# %%
describe_calendar_listing_id['available']['top'].describe()
# Out:
# count     3818
# unique       2
# top          t
# freq      2475
# Name: top, dtype: object

# %%
calendar_groupby2 = calendar.groupby(['listing_id', 'date', 'available'])

# %%
calendar_crosstab = pd.crosstab(calendar.listing_id, calendar.date, values=calendar.available, aggfunc='first')

# %%
calendar_crosstab = calendar_crosstab.replace(to_replace='f', value=1).replace(to_replace='t', value=0)

# %%
calendar_crosstab_T = calendar_crosstab.T

# %%
calendar_crosstab_T.sum().sort_values().to_csv('test.csv')

# %%
calendar_crosstab_T[1251707];

# %%
listings[listings.id == 1762354].T.to_csv('test.csv')

# %%
sum_ = calendar_crosstab_T.sum().to_frame()
len(sum_[sum_[0] == 0])
len(sum_[sum_[0] < 5])
sum_[sum_[0] == 365]
# Out:
#               0
# listing_id
# 107046      365
# 284813      365
# 445199      365
# 777159      365
# 1030411     365
# 1049293     365
# 1209447     365
# 1762354     365
# 1961671     365
# 2277640     365
# 2350464     365
# 2426152     365
# 2489339     365
# 2808357     365
# 3124961     365
# 3215404     365
# 3345341     365
# 3386862     365
# 3533112     365
# 3534444     365
# 3593582     365
# 3728802     365
# 3759039     365
# 3766285     365
# 3773700     365
# 3783162     365
# 3793406     365
# 3812725     365
# 3930681     365
# 3993960     365
# ...         ...
# 6824408     365
# 6993726     365
# 7382368     365
# 7420339     365
# 7437784     365
# 7581974     365
# 7922676     365
# 7952032     365
# 8171726     365
# 8194886     365
# 8241019     365
# 8253758     365
# 8339428     365
# 8369321     365
# 8441263     365
# 8717068     365
# 8811945     365
# 9095668     365
# 9364302     365
# 9562586     365
# 9699490     365
# 9900303     365
# ...

# %%
calendar_crosstab_T.sum().sort_values().hist(grid=False, bins=91)

# %%
plt.figure(figsize = (32,20))
sns.heatmap(calendar_crosstab, xticklabels=False, yticklabels=False, cmap='Blues')

# %% [markdown]
# # What to do next:
# - Checking availibility pattern
# - Checking latitude longitude pattern
# - Checking price correlation
